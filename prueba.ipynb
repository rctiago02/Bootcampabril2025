# %%
# Definir intentos, palabra secreta, la cantidad de letras en base a la palabra secreta, la lista de caracteres de la palabra secreta y un contador
intentos = 3
intentos = int(input("ingrese una cantidad de intentos"))
palabra_secreta = input("ingrese una palabra secreta")
lista_palabra_secreta = list(palabra_secreta)
contador = 0

# Cuenta cuantos caracteres tiene la palabra secreta
cantidad_letras_secreta = len(palabra_secreta)

# establece una variable para un caracter espacio " "
letras_vacias = " "

# cuanta la cantidad de caracteres espacio (1)
cantidad_letras_vacias = len(letras_vacias)


# mientras la variable de la cantidad de letras de la palabra ingresada no sea igual a la cantidad de letras vacias suma un caracter a la variable letras vacias
while cantidad_letras_vacias != cantidad_letras_secreta:
    letras_vacias = letras_vacias + " "
    # vuelve a contar la cantidad de caracteres en la variable letras vacias
    cantidad_letras_vacias = len(letras_vacias)
    


# Crea una lista vacia con cada caracter de letras vacias (espacios en cada caracter)
lista_vacia = [list(letras_vacias)]


# Convierte la palabra ingresada en una lista
lista_palabra_ingresada = [list(palabra_ingresada)]


# A la variable lista_vacia se multiplica la cantidad de intentos
lista_vacia = lista_vacia * intentos


# comienza codigo

# Mientras intentos no sea igual a 0 : COMIENZAAAA!!!!


while intentos > 0:

    # Pide al usuario que ingrese su palabra y crea una variable de cuenta cuantos caracteres tiene la palabra ingresada
    palabra_ingresada = input(f"ingresa una palabra con {cantidad_letras_secreta} letras")
    cantidad_letras_ingresadas = len(palabra_ingresada)

    # Convierte la palabra ingresada en una lista
    lista_palabra_ingresada = [list(palabra_ingresada)]

    while cantidad_letras_ingresadas == cantidad_letras_secreta:
        
        # Se Cambia la primera lista de lista vacia por la lista de caracteres de la palabra ingresada
        lista_vacia[contador] = lista_palabra_ingresada

        # Imprime la cantidad de intentos con la lista vacia
        for imprimir in lista_vacia:
            print(imprimir)
        
        intentos = intentos - 1

        # Creamos una variable contador para la impresion de cada palabra ingresada
        contador = contador + 1

        # Si la lista de la palabra ingresada es igual a la lista de palabra secreta rompe el ciclo. GANASTE!!!
        if palabra_ingresada == palabra_secreta:
            print("Ganasteeee!!!!")
            break
        else:
            palabra_ingresada = input(f"ingresa una palabra de {cantidad_letras_secreta} letras")
            lista_palabra_ingresada = list(palabra_ingresada)
            cantidad_letras_ingresadas = len(palabra_ingresada)
            




print("Perdiste pero aprendiste a codear maldito")
# Out:
# [['m', 'o', 'n', 'o']]
# [' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ']

# %%
# Definir intentos, palabra secreta, la cantidad de letras en base a la palabra secreta, la lista de caracteres de la palabra secreta y un contador
intentos = 3
intentos = int(input("ingrese una cantidad de intentos"))
palabra_secreta = input("ingrese una palabra secreta")
lista_palabra_secreta = list(palabra_secreta)
contador = 0

# Cuenta cuantos caracteres tiene la palabra secreta
cantidad_letras_secreta = len(palabra_secreta)

# establece una variable para un caracter espacio " "
letras_vacias = " "

# cuanta la cantidad de caracteres espacio (1)
cantidad_letras_vacias = len(letras_vacias)


# mientras la variable de la cantidad de letras de la palabra ingresada no sea igual a la cantidad de letras vacias suma un caracter a la variable letras vacias
while cantidad_letras_vacias != cantidad_letras_secreta:
    letras_vacias = letras_vacias + " "
    # vuelve a contar la cantidad de caracteres en la variable letras vacias
    cantidad_letras_vacias = len(letras_vacias)
    


# Crea una lista vacia con cada caracter de letras vacias (espacios en cada caracter)
lista_vacia = [list(letras_vacias)]


# Convierte la palabra ingresada en una lista
lista_palabra_ingresada = [list(palabra_ingresada)]


# A la variable lista_vacia se multiplica la cantidad de intentos
lista_vacia = lista_vacia * intentos


# comienza codigo

# Mientras intentos no sea igual a 0 : COMIENZAAAA!!!!


while intentos > 0:

    # Pide al usuario que ingrese su palabra y crea una variable de cuenta cuantos caracteres tiene la palabra ingresada
    palabra_ingresada = input(f"ingresa una palabra con {cantidad_letras_secreta} letras")
    cantidad_letras_ingresadas = len(palabra_ingresada)

    # Convierte la palabra ingresada en una lista
    lista_palabra_ingresada = [list(palabra_ingresada)]


    
    while cantidad_letras_ingresadas == cantidad_letras_secreta:
        
        # Se Cambia la primera lista de lista vacia por la lista de caracteres de la palabra ingresada
        lista_vacia[contador] = lista_palabra_ingresada




        # Creamos una variable contador para la impresion de cada palabra ingresada
        contador = contador + 1

        # Si la lista de la palabra ingresada es igual a la lista de palabra secreta rompe el ciclo. GANASTE!!!
        if palabra_ingresada == palabra_secreta:
            print("Ganasteeee!!!!")
            break
        else:
            palabra_ingresada = input(f"ingresa una palabra de {cantidad_letras_secreta} letras")
            lista_palabra_ingresada = list(palabra_ingresada)
            cantidad_letras_ingresadas = len(palabra_ingresada)

        # resta el numero de intentos
        intentos = intentos - 1

                # Imprime la cantidad de intentos con la lista vacia
        for imprimir in lista_vacia:
            print(imprimir)
        
            


print("Perdiste pero aprendiste a codear maldito")

# %% [markdown]
# ## EL TRUEEEE

# %%
# Definir intentos, palabra secreta, la cantidad de letras en base a la palabra secreta, la lista de caracteres de la palabra secreta y un contador_list
intentos = 3
intentos = int(input("ingrese una cantidad de intentos"))
palabra_secreta = input("ingrese una palabra secreta")
lista_palabra_secreta = list(palabra_secreta)
contador_list = 0

# Cuenta cuantos caracteres tiene la palabra secreta
cantidad_letras_secreta = len(palabra_secreta)

# establece una variable para un caracter espacio " "
letras_vacias = " "

# cuanta la cantidad de caracteres espacio (1)
cantidad_letras_vacias = len(letras_vacias)


# mientras la variable de la cantidad de letras de la palabra ingresada no sea igual a la cantidad de letras vacias suma un caracter a la variable letras vacias
while cantidad_letras_vacias != cantidad_letras_secreta:
    letras_vacias = letras_vacias + " "
    # vuelve a contar la cantidad de caracteres en la variable letras vacias
    cantidad_letras_vacias = len(letras_vacias)
    


# Crea una lista vacia con cada caracter de letras vacias (espacios en cada caracter)
lista_vacia = [list(letras_vacias)]



# A la variable lista_vacia se multiplica la cantidad de intentos
lista_vacia = lista_vacia * intentos


# Ingresa una palabra y define una cantidad de caracteres de la palabra ingresada
palabra_ingresada = input(f"ingresa una palabra de {cantidad_letras_secreta} letras")
cantidad_letras_ingresadas = len(palabra_ingresada)

# Convierte la palabra ingresada en una lista
lista_palabra_ingresada = [list(palabra_ingresada)]

# comienza codigo

# Mientras intentos no sea igual a 0 : COMIENZAAAA!!!!


while intentos > 0:

    lista_vacia[contador_list] = lista_palabra_ingresada
    # Imprime la cantidad de intentos con la lista vacia
    for imprimir in lista_vacia:
        print(imprimir)

    while cantidad_letras_ingresadas != cantidad_letras_secreta:
        palabra_ingresada = input(f"La cantidad de letras es de {cantidad_letras_secreta} letras, elije otra palabra")
        cantidad_letras_ingresadas = len(palabra_ingresada)
        lista_palabra_ingresada = [list(palabra_ingresada)]
         
    print(f"te quedan {intentos} intentos")


    # resta el numero de intentos
    intentos = intentos - 1
    contador_list = contador_list + 1

  
    if palabra_ingresada == palabra_secreta:
        print("ganaste")
        break

print("Perdiste")
# Out:
# [['m', 'o', 'n', 'o']]
# [' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ']
# te quedan 2 intentos
# [['m', 'o', 'n', 'o']]
# [['m', 'o', 'n', 'o']]
# [' ', ' ', ' ', ' ']
# te quedan 0 intentos
# Perdiste
